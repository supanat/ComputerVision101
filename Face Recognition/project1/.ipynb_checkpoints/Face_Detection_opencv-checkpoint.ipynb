# %%
#!wget https://raw.githubusercontent.com/Itseez/opencv/master/data/haarcascades/haarcascade_frontalface_alt2.xml
#!wget https://raw.githubusercontent.com/Itseez/opencv/master/data/haarcascades/haarcascade_eye.xml
#!open . # open current folder to check dowloaded file

# %% [markdown]
# ### Face Detection
# https://docs.opencv.org/master/d7/d8b/tutorial_py_face_detection.html

# %%
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
hc = cv2.CascadeClassifier("haarcascade_frontalface_alt2.xml")

# %%
img = cv2.imread("../image/ss02.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')

# %%
faces = hc.detectMultiScale(gray)

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

cv2.imwrite('out.jpg',img)
# Out:
# True

# %%
faces = hc.detectMultiScale(gray)

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    plt.imshow(roi_gray,cmap='gray')
    
#plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
