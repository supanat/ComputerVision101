# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline 

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = cv2.imread("../images/trex.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
canvas = np.zeros((300, 300, 3), dtype = "uint8")
canvas.shape
# Out:
# (300, 300, 3)

# %%
plt.imshow(canvas)

# %%
canvas[0:300,0:300] = [0,255,0]
plt.imshow(canvas)

# %%
green = (0, 255, 0)
red = (255, 0, 0)

# %%
canvas[0:300,0:300] = [0,0,0]

cv2.line(canvas, (0, 0), (200, 200), green)
plt.imshow(canvas)

# %%
canvas[0:300,0:300] = [0,0,0]
cv2.rectangle(canvas, (10, 10), (120, 150), green,2)
cv2.rectangle(canvas, (50, 200), (200, 225), red, 5)
plt.imshow(canvas)

# %%
canvas = np.zeros((300, 300, 3), dtype = "uint8")

centerX, centerY = (canvas.shape[1] // 2, canvas.shape[0] // 2)

white = (255, 255, 255)

r = 25

for i in range(1,10):
    cv2.circle(canvas, (centerX, centerY), r*i, white)
    

plt.figure(figsize=(10,10))
plt.imshow(canvas)
plt.savefig('canvas1.png')

# %%
centerX, centerY = (image.shape[1] // 2, image.shape[0] // 2)
r = 25

yellow = (255, 255, 0)

for i in range(1,10):
    cv2.circle(image, (centerX, centerY), r*i, yellow)
    

plt.figure(figsize=(10,10))
plt.imshow(image)
plt.savefig('canvas2.png')
