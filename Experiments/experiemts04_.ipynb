# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline 

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = cv2.imread("../images/trex.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# Convert BGR to RGB

##image = mpimg.imread('../images/blue.png')

# mpimg.imread

# %%
plt.imshow(image)

# %%
image[0, 0]
# Out:
# array([254, 254, 254], dtype=uint8)

# %%
r,g,b = image[0, 0]
r,g,b
# Out:
# (254, 254, 254)

# %%
corner = image[0:100, 0:100]
plt.imshow(corner)

# %%
image[0:100, 0:100] = (0, 255, 0)
plt.imshow(image)

# %%
image[100, 0:100] = (255, 0, 0)
plt.imshow(image)
