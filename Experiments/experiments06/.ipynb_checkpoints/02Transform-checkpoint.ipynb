# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib notebook 

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import math

# %%
image = cv2.imread("../../images/trex.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure("Original")
plt.title("Original")
plt.imshow(image)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# !pip install imutils
# Out:
# ...
#   Running setup.py bdist_wheel for imutils ... done
#   Stored in directory: /Users/supanat/Library/Caches/pip/wheels/cb/58/9b/7debccbc53159611f67cc7e2e3ed37b217e56e9b40e7ba80c3
# Successfully built imutils
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import imutils

# %% [markdown]
# ### Translation

# %%
shifted = imutils.translate(image, 0, 100)
plt.figure("Shifted")
plt.imshow(shifted)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
cv2.imwrite("shifted_trex.png",shifted)
# Out:
# True

# %% [markdown]
# ### Rotate

# %%
rotated = imutils.rotate(image, 90)
plt.figure("rotated")
plt.imshow(rotated)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Resize

# %%
resized = imutils.resize(image, width = 100)
plt.figure("resized")
plt.imshow(resized)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Flipping

# %%
h_flipped = cv2.flip(image, 1)
v_flipped = cv2.flip(image, 0)

plt.figure('Image Rotation')
plt.subplot(121) #1ROW,2COL,INDEX 1
plt.imshow(h_flipped) 
plt.title('Flip Horizontal')
plt.axis('off')

plt.subplot(122) #1ROW,2COL,INDEX 2
plt.imshow(v_flipped)
plt.title('Flip Vertical')
plt.axis('off')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
